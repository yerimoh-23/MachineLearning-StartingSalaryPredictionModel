# %%
#Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tuition_income = pd.read_csv('/content/drive/MyDrive/COMSC335/CourseProject/tuition_income.csv')
tuition_cost = pd.read_csv('/content/drive/MyDrive/COMSC335/CourseProject/tuition_cost.csv')

# %%
tuition_income = tuition_income.dropna()
tuition_cost = tuition_cost.dropna()

# %%
tuition_income
# Out:
#                                      name state  total_price  year  \
# 0       Piedmont International University    NC        20174  2016
# 1       Piedmont International University    NC        20174  2016
# 2       Piedmont International University    NC        20174  2016
# 3       Piedmont International University    NC        20174  2016
# 4       Piedmont International University    NC        20514  2017
# ...                                   ...   ...          ...   ...
# 209007           Alabama A & M University    AL        23462  2018
# 209008           Alabama A & M University    AL        23462  2018
# 209009           Alabama A & M University    AL        23462  2018
# 209010           Alabama A & M University    AL        23462  2018
# 209011           Alabama A & M University    AL        23462  2018
#
#             campus     net_cost         income_lvl
# 0        On Campus  11475.00000        0 to 30,000
# 1        On Campus  11451.00000   30,001 to 48,000
# ...

# %%
tuition_cost
# Out:
#                                       name         state state_code  \
# 1             Abilene Christian University         Texas         TX
# 2     Abraham Baldwin Agricultural College       Georgia         GA
# 4                Academy of Art University    California         CA
# 5                   Adams State University      Colorado         CO
# 6                       Adelphi University      New York         NY
# ...                                    ...           ...        ...
# 2964                     Yeshivath Viznitz      New York         NY
# 2965                          York College      Nebraska         NE
# 2966          York College of Pennsylvania  Pennsylvania         PA
# 2969                  Young Harris College       Georgia         GA
# 2970           Youngstown State University          Ohio         OH
#
#             type degree_length  room_and_board  in_state_tuition  \
# 1        Private        4 Year         10350.0             34850
# ...

# %%
tuition_cost = tuition_cost[['name', 'type','degree_length', 'in_state_total', 'out_of_state_total']]

# %%
tuition_income = tuition_income[['name','net_cost']].groupby(['name']).first().reset_index()

# %%
tuition = tuition_income.merge(right = tuition_cost, on = 'name')
tuition
# Out:
#                                       name  net_cost        type  \
# 0                              ASA College   20916.0  For Profit
# 1             Abilene Christian University   21258.0     Private
# 2     Abraham Baldwin Agricultural College    6026.0      Public
# 3                Academy of Art University   28284.0  For Profit
# 4                   Adams State University    9163.0      Public
# ...                                    ...       ...         ...
# 1484                     Yeshivath Viznitz    7300.0     Private
# 1485                          York College   16497.0     Private
# 1486          York College of Pennsylvania   15762.0     Private
# 1487                  Young Harris College   10997.0     Private
# 1488           Youngstown State University   10224.0      Public
#
#      degree_length  in_state_total  out_of_state_total
# 0           2 Year           23565               23565
# 1           4 Year           45200               45200
# ...

# %%
tuition['net_cost'] = tuition['net_cost'].round(2)
tuition
# Out:
#                                       name  net_cost        type  \
# 0                              ASA College   20916.0  For Profit
# 1             Abilene Christian University   21258.0     Private
# 2     Abraham Baldwin Agricultural College    6026.0      Public
# 3                Academy of Art University   28284.0  For Profit
# 4                   Adams State University    9163.0      Public
# ...                                    ...       ...         ...
# 1484                     Yeshivath Viznitz    7300.0     Private
# 1485                          York College   16497.0     Private
# 1486          York College of Pennsylvania   15762.0     Private
# 1487                  Young Harris College   10997.0     Private
# 1488           Youngstown State University   10224.0      Public
#
#      degree_length  in_state_total  out_of_state_total
# 0           2 Year           23565               23565
# 1           4 Year           45200               45200
# ...

# %%
tuition.to_csv('/content/drive/My Drive/tuition.csv', index=False)
