# %%
#Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read files
diversity = pd.read_csv('/content/drive/MyDrive/new_diversity.csv')
salary_potential = pd.read_csv('/content/drive/MyDrive/salary_potential.csv')
tuition = pd.read_csv('/content/drive/MyDrive/tuition.csv')

# %%
# merge dataset
college = diversity.merge(right = salary_potential, on = 'name').merge(right = tuition, on = 'name')
college['degree_length'].unique()
# Out:
# array(['4 Year'], dtype=object)

# %%
college
# Out:
#         Unnamed: 0                           name  total_enrollment  \
# 0               70  University of Central Florida             60767
# 1               70  University of Central Florida             60767
# 2               70  University of Central Florida             60767
# 3               70  University of Central Florida             60767
# 4               70  University of Central Florida             60767
# ...            ...                            ...               ...
# 279811       19398             Bloomfield College              2004
# 279812       19398             Bloomfield College              2004
# 279813       19398             Bloomfield College              2004
# 279814       19398             Bloomfield College              2004
# 279815       19398             Bloomfield College              2004
#
#            state_x                   race/ethnicity  enrollment  \
# 0          Florida  American Indian / Alaska Native         120
# ...

# %%
college.to_csv('/content/drive/My Drive/college.csv', index=False)

# %%
#college = college[college['state'] == 'Massachusetts']
#college
